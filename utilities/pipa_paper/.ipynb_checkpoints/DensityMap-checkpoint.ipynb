# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import matplotlib
from matplotlib import colors,colorbar
import matplotlib
# %matplotlib inline
import csv 
import math

# %%
def get_area(lat):
    lat_degree = 69 #miles
    # Convert latitude and longitude to 
    # spherical coordinates in radians.
    degrees_to_radians = math.pi/180.0        
    # phi = 90 - latitude
    phi = (lat+.05)*degrees_to_radians #plus 0.5 to get the middle
    lon_degree = math.cos(phi)*69 #miles
    # return 69*69*2.6
    return  lat_degree*lon_degree* 2.58999 #miles to square km

# %%
sourcedir = "../../data/density/"
filename = "003.csv"


vessel_days = np.zeros(shape=(1800,3600))


test_array = np.zeros(shape=(3600))
test_array2 = np.zeros(shape=(3600))


with open(sourcedir + filename,'rU') as f:
    reader = csv.DictReader(f, delimiter=',')
    for row in reader:
        if row['lon_bin'] == "-179.3":
            print float(row['lon_bin'])
        lat = float(row['lat_bin'])+90
        lon = float(row['lon_bin'])+180
        if lat<180 and lat>-1 and lon>-1 and lon<360:
            lat_index = int(lat*10)
            lon_index = int(lon*10)
            days = int(row['number'])

            area = get_area(lat-90) # area of 1 by 1 degree at a given lat
            vessel_days[lat_index][lon_index] = days / (365* area*.1*.1) * 100000. #vessels per day per 10^5 square km
            if float(row['lat_bin']) > 30 or float(row['lat_bin']) < 35:
                test_array[lon_index] += vessel_days[lat_index][lon_index]
                test_array2[lon_index] += 1

for i in range(500):
    pass #print i,"\t", i/10.-180,"\t",test_array[i], "\t", test_array2[i]
# Out:
# {'lat_bin': '54', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '-12.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '7.5', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '3.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-5.1', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '48.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-31.7', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-17.5', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '61.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-4.5', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-4.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '53.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-36.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '64', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-13.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-2.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '32.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '47.8', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '39.1', 'number': '6', 'lon_bin': '-179.3'}
# {'lat_bin': '-5.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-20.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '63.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '54.5', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '1.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '5', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '29.8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '62.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-15.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '7.2', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '45.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-4.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '63.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '69', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-18.4', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '64.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-77.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-32.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '31.3', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '53.2', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '65', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '42', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-28.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-3.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-44', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-15.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '13.6', 'number': '5', 'lon_bin': '-179.3'}
# {'lat_bin': '46.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '44.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '9.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '44.1', 'number': '5', 'lon_bin': '-179.3'}
# {'lat_bin': '68.9', 'number': '15', 'lon_bin': '-179.3'}
# {'lat_bin': '-27.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '27', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-18.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '27.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-9.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '31', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '54.2', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '-7.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-39.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '20.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-50.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '45.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-3.2', 'number': '6', 'lon_bin': '-179.3'}
# {'lat_bin': '-77', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-23.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '14.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '11.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-28.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-27.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '39.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '30.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '46.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '22.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '20.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-0.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '32.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '12.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '54.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '11.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '63.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '5.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-21.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-34.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '34.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-3.8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '17', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '3.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '54.1', 'number': '14', 'lon_bin': '-179.3'}
# {'lat_bin': '53.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '38.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-26.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-21.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-25.4', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '55.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '41.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-16.6', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '-8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-2.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-43', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-6.7', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '0.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-43.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '35', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-4.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-2.8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-17.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-3.4', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '32.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-1.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '55.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '51.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '48.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-20', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '50.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '32.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '31.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-7.7', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-7.9', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '61.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-71.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-18.2', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '-44.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '43.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-25.2', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '-26.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-16', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-5.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '6.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '47.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '10.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-13.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '26.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '37.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '40.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '25.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '46.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '26', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '43.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-6.4', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '53.8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '54.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-21.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '49.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '12.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-19.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '40.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '19.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '2.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-24.2', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-16.7', 'number': '7', 'lon_bin': '-179.3'}
# {'lat_bin': '61.7', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '47.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '29.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '8.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-15.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-16.8', 'number': '11', 'lon_bin': '-179.3'}
# {'lat_bin': '48.2', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '40.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-16.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-6.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '61.2', 'number': '8', 'lon_bin': '-179.3'}
# {'lat_bin': '27.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '38.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-27.7', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-25.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '37.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '31.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-37.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '11.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '48.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '12.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-9.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-3.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-17.8', 'number': '5', 'lon_bin': '-179.3'}
# {'lat_bin': '62.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '33.7', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '41.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-15.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '6.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '41.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '45.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '38.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '62', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '61.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-6.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '12.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '10.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '60.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '52.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-4.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-0.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-17.7', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '53.3', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '29.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '18.7', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-8.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '4.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-17.2', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '44.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '41.8', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '53.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-23.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '30', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-22.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '40.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '6.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-19', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-3.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '29.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '11.2', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '45', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '47.6', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '21.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-25.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '39', 'number': '10', 'lon_bin': '-179.3'}
# {'lat_bin': '18.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-3.9', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '-17.3', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '31.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-19.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '21', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '40.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-18.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-11.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '29.7', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-16.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-24.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-43.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-10.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '1.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '51', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '61.1', 'number': '10', 'lon_bin': '-179.3'}
# {'lat_bin': '-17.6', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '14', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-21.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-2.5', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '33', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '31.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '49.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '50.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '61.8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-1.8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '16.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '43.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-4', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '44.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '44.4', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '4.5', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '54.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '62.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-27.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '12.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '55.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-17.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-2.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '50.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-19.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '39.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-5.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '47.4', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '33.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '50.3', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '-2.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '9.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '64.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-5.5', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '-7.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '17.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '63.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '62.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '64.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '40.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '13.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '24.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '33.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '21.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '60.7', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '20.8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '61.4', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '53', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '49', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-11.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-36.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-32.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-28.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-8.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '53.4', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-25.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '5.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '5.3', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '-35.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '10.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '46.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '46.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '13.8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-22.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '43.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '10.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '61.3', 'number': '6', 'lon_bin': '-179.3'}
# {'lat_bin': '47.5', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '65.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '49.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '10.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '8.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-3.6', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '63.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '22.5', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '29.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '44.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-23.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '60.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '53.5', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-19.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '52.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '11.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-44.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-6.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '46.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-31.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '48.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-17.4', 'number': '8', 'lon_bin': '-179.3'}
# {'lat_bin': '12.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '36.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '23.4', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '30.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-2.4', 'number': '6', 'lon_bin': '-179.3'}
# {'lat_bin': '54.6', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '-28.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '36.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '33.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-26.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '0', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '66.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-34.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '23.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '2.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '47.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '45.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-5.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '30.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '3.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '63.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '44.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '41.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '72.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '61', 'number': '17', 'lon_bin': '-179.3'}
# {'lat_bin': '65.5', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '30.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '52.7', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '48.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '3.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-25.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '50.1', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '32.2', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '4.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-18.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '0.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '1.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '50', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '-2.3', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '18.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '53.7', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-0.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-11.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '31.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '60.9', 'number': '8', 'lon_bin': '-179.3'}
# {'lat_bin': '62.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '33.6', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '5.4', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '60.5', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '46.4', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '7.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '50.2', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '48.5', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '54.8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-24.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-33.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '55.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '42.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-6.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '4.9', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '65.2', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-16.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '30.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-16.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-22.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '49.2', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-42.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '33.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '49.6', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-77.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-42.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '49.8', 'number': '4', 'lon_bin': '-179.3'}
# {'lat_bin': '34.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '45.3', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-24.8', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-2.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-10.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '34.1', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '20.6', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '17.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-15.8', 'number': '2', 'lon_bin': '-179.3'}
# {'lat_bin': '-33', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '19.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '34.9', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '2.5', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '65.4', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '38.9', 'number': '3', 'lon_bin': '-179.3'}
# {'lat_bin': '5.1', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '48.4', 'number': '1', 'lon_bin': '-179.3'}
# {'lat_bin': '-17', 'number': '1', 'lon_bin': '-179.3'}

# %%
tm = 1000. #this is just to scale the the following... this makes the colormap



colors = [["#FFFFFF",0,0],
          ['#894081', 5,5],
          ['#338ACA',10,10],
          ['#47AEC4',25,25],
          ['#49A578',50,50],
          ['#82B130',100,100],
          ['#F8C728',250,250],
          ['#EFA639',500,500],
          ['#E58230',1000,1000]]
          
                 
          
          
cdict = { 'red':tuple(   (color[2]/tm, int(color[0][1:3],16)/256.0, int(color[0][1:3],16)/256.0) for color in colors ),
          'green':tuple( (color[2]/tm, int(color[0][3:5],16)/256.0, int(color[0][3:5],16)/256.0) for color in colors ),
          'blue':tuple(  (color[2]/tm, int(color[0][5:7],16)/256.0, int(color[0][5:7],16)/256.0) for color in colors )}


tm = 1000.

# colors = colors[1:]
# for i in range(len(colors)):
#     colors[i] = [colors[i][0], colors[i][1]-1, colors[i][2]-1]


cdict2 = { 'red':tuple(   (color[2]/tm, int(color[0][1:3],16)/256.0, int(color[0][1:3],16)/256.0) for color in colors ),
          'green':tuple( (color[2]/tm, int(color[0][3:5],16)/256.0, int(color[0][3:5],16)/256.0) for color in colors ),
          'blue':tuple(  (color[2]/tm, int(color[0][5:7],16)/256.0, int(color[0][5:7],16)/256.0) for color in colors )}#,
          #'alpha': ((0,0,0),(.00001,1,1),(1,1,1)) }



'''#I left the following in just to show the format of the colormap -- it is a series of tuples
cdict = {'red': ((0.0, 0.0, 0.0),
                  (0.5, 1.0, 0.7),
                  (1.0, 1.0, 1.0)),
          'green': ((0.0, 0.0, 0.0),
                    (0.5, 1.0, 0.0),
                    (1.0, 1.0, 1.0)),
          'blue': ((0.0, 0.0, 0.0),
                   (0.5, 1.0, 0.0),
                   (1.0, 0.5, 1.0))}
'''
my_cmap = matplotlib.colors.LinearSegmentedColormap('my_colormap',cdict,256)
my_cmap.set_bad(alpha = 0.0)
    
my_cmap2 = matplotlib.colors.LinearSegmentedColormap('my_colormap',cdict2,256)
my_cmap2.set_bad(alpha = 0.0)  

firstlat = 90
lastlat = -90
firstlon = -180
lastlon = 180
scale = .1

numlats = int((firstlat-lastlat)/scale+.5)
numlons = int((lastlon-firstlon)/scale+.5)
    
#     data_array = np.zeros((numlats, numlons)) #data_array is in format data_array[lat index][lon index]

lat_boxes = np.linspace(lastlat,firstlat,num=numlats,endpoint=False)
lon_boxes = np.linspace(firstlon,lastlon,num=numlons,endpoint=False)


fig = plt.figure()


m = Basemap(llcrnrlat=lastlat, urcrnrlat=firstlat,
          llcrnrlon=firstlon, urcrnrlon=lastlon, lat_ts=0, projection='mill',resolution="h")

m.drawmapboundary()
#     m.drawcoastlines(linewidth=.2)
m.fillcontinents('#555555')#, lake_color, ax, zorder, alpha)


x = np.linspace(-180, 180, 360*10 )
y = np.linspace(lastlat, firstlat, (firstlat-lastlat)*10)
x, y = np.meshgrid(x, y)
converted_x, converted_y = m(x, y)
from matplotlib import colors,colorbar

norm = colors.LogNorm(vmin=1, vmax=1000)

m3 = 10

m.pcolormesh(converted_x, converted_y, vessel_days, norm=norm, vmin=1, vmax=m3**3)
#plt.pcolormesh(x, y, z, cmap='RdBu', vmin=z_min, vmax=z_max)

t = "Density of Vessels per Day, 2015"
plt.title(t)
# topodat = m.transform_scalar(gap_buckets,lon_boxes,lat_boxes,nx,ny)
# 
# im = m.imshow(topodat,interpolation='none',vmin=-1,vmax=10,cmap=my_cmap,zorder = 0,alpha=1)#,norm=LogNorm(vmin=0.00000001, vmax=.00064))#cm.s3pcpn)#,)


# cbar = fig.colorbar(im)#, ticks=[-1, 0, 1])
# theticks = [i*100 for i in range(10)]
# cbar = fig.colorbar(im, cmap =my_cmap2, orientation='horizontal')

ax = fig.add_axes([0.15, 0.1, 0.4, 0.02]) #x coordinate , 
#ax.patch.set_alpha(0.0)
#ax.axis('off')
# my_cmap=choose_cmap('reds')
norm = colors.Normalize(vmin=0, vmax=1000)
norm = colors.LogNorm(vmin=1, vmax=1000)
lvls = np.logspace(0,3,7)

cb = colorbar.ColorbarBase(ax,norm = norm,
#                                     ticks=theticks,
                                   orientation='horizontal', ticks=lvls)


cb.ax.set_xticklabels(["<1" ,int(m3**.5), m3, int(m3**1.5), m3*m3,int(m3**2.5), str(int(m3**3))+"+"], fontsize=10)
cb.set_label('Vessels per day per 10^5 km^2',labelpad=-40, y=0.45)

# plt.text(1.1, .15, 'Pixels with fewer than 20 boats per\nday in 2014 are shown in gray', fontsize = 10)
# plt.axis('off')


plt.rcParams["figure.figsize"] = [12,8]

plt.show()
#plt.savefig("vessel_density_2015_first_b_t.png",bbox_inches='tight',dpi=450,transparent=True,pad_inches=0)

#plt.clf()
